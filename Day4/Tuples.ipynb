# %% [markdown]
# # Tuples

# %%
tuple = ("Sunny", "Bunny", "Surya", "Sonu")
print(tuple)
# Out:
# ('Sunny', 'Bunny', 'Surya', 'Sonu')

# %%
type(tuple)
# Out:
# tuple

# %%
#in built function
tuple.count("Sunny")
# Out:
# 1

# %%
tuple.index("Sonu")
# Out:
# 3

# %% [markdown]
# ##### copy
# ##### shallow copy

# %%
lst1 = [2, 4, 6, 8, 10]
lst2 = lst1

# %%
lst2[1] =1000

# %%
lst2, lst1
# Out:
# ([2, 1000, 6, 8, 10], [2, 1000, 6, 8, 10])

# %%
lst1 = [[1,2,3,4], [5,6,7,8]]
lst2= lst1.copy()

# %%
lst1[1][0]=100
lst2
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8]]

# %%
import copy
lst1 = [1,2,3,4,5]
lst2 = copy.deepcopy(lst1)

# %%
lst2[1]=100

# %%
lst2
# Out:
# [[1, 2, 3, 4], 100]

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_json("http://127.0.0.1:8000/api/credentials/?format=json")
df.head()
# Out:
#    id username  password
# 0   1    sunny     12345
# 1   2    vinay  ertyuikl
# 2   3     anuj  dcfvgbnm
